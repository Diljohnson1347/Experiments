# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('HeartDisease.csv')

# %%
df.head()
# Out:
#    age  gender  chest_pain  rest_bps  cholestrol  fasting_blood_sugar  \
# 0   63       1           3       145         233                    1
# 1   37       1           2       130         250                    0
# 2   41       0           1       130         204                    0
# 3   56       1           1       120         236                    0
# 4   57       0           0       120         354                    0
#
#    rest_ecg  thalach  exer_angina  old_peak  slope  ca  thalassemia  target
# 0         0      150            0       2.3      0   0            1       1
# 1         1      187            0       3.5      0   0            2       1
# 2         0      172            0       1.4      2   0            2       1
# 3         1      178            0       0.8      2   0            2       1
# 4         1      163            1       0.6      2   0            2       1

# %% [markdown]
# ### EDA

# %%
#No null values
df.isnull().sum()
# Out:
# age                    0
# gender                 0
# chest_pain             0
# rest_bps               0
# cholestrol             0
# fasting_blood_sugar    0
# rest_ecg               0
# thalach                0
# exer_angina            0
# old_peak               0
# slope                  0
# ca                     0
# thalassemia            0
# target                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  303 non-null    int64
#  1   gender               303 non-null    int64
#  2   chest_pain           303 non-null    int64
#  3   rest_bps             303 non-null    int64
#  4   cholestrol           303 non-null    int64
#  5   fasting_blood_sugar  303 non-null    int64
#  6   rest_ecg             303 non-null    int64
#  7   thalach              303 non-null    int64
#  8   exer_angina          303 non-null    int64
#  9   old_peak             303 non-null    float64
#  10  slope                303 non-null    int64
#  11  ca                   303 non-null    int64
#  12  thalassemia          303 non-null    int64
#  13  target               303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
import pandas_profiling
pandas_profiling.ProfileReport(df)
# Out:
# ...
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v2.10.1&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-03-01 15:06:49.231881&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#Most of patients lie between the age range of 40 to 70
sns.histplot(x = 'age', data = df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x = 'target', y = 'age', data = df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='age'>

# %%
#More Females in this dataset
sns.countplot(x = 'gender', data = df)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
#Percentage to males having heart disease is more than that of females
pd.crosstab(df['gender'], df['target'], margins = all)
# Out:
# target    0    1  All
# gender
# 0        24   72   96
# 1       114   93  207
# All     138  165  303

# %%
sns.countplot(x = 'chest_pain', data = df)
# Out:
# <AxesSubplot:xlabel='chest_pain', ylabel='count'>

# %%
#If the patient is having chest pain, then it is more likely that the patient has a heart disease
pd.crosstab(df['chest_pain'], df['target'], margins = all)
# Out:
# target        0    1  All
# chest_pain
# 0           104   39  143
# 1             9   41   50
# 2            18   69   87
# 3             7   16   23
# All         138  165  303

# %%
sns.histplot(x = 'rest_bps', data = df)
# Out:
# <AxesSubplot:xlabel='rest_bps', ylabel='Count'>

# %%
sns.boxplot(x = 'target', y = 'rest_bps', data = df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='rest_bps'>

# %%
#Typical range is from around 150 to 350
sns.histplot(x = 'cholestrol', data = df)
# Out:
# <AxesSubplot:xlabel='cholestrol', ylabel='Count'>

# %%
sns.boxplot(x = 'target', y = 'cholestrol', data = df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='cholestrol'>

# %%
sns.countplot(x = 'fasting_blood_sugar', data = df)
# Out:
# <AxesSubplot:xlabel='fasting_blood_sugar', ylabel='count'>

# %%
df.drop('fasting_blood_sugar', axis = 1, inplace = True)

# %%
sns.countplot(x = 'rest_ecg', data = df)
# Out:
# <AxesSubplot:xlabel='rest_ecg', ylabel='count'>

# %%
pd.crosstab(df['rest_ecg'], df['target'], margins = all)
# Out:
# target      0    1  All
# rest_ecg
# 0          79   68  147
# 1          56   96  152
# 2           3    1    4
# All       138  165  303

# %%
sns.histplot(x = 'thalach', data = df)
# Out:
# <AxesSubplot:xlabel='thalach', ylabel='Count'>

# %%
sns.boxplot(x = 'target', y = 'thalach', data = df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='thalach'>

# %%
sns.countplot(x = 'exer_angina', data = df)
# Out:
# <AxesSubplot:xlabel='exer_angina', ylabel='count'>

# %%
#If the patient has angina induced due to exercise, then it is more likely that the patient doesn't have any heart disease
pd.crosstab(df['exer_angina'], df['target'], margins = all)
# Out:
# target         0    1  All
# exer_angina
# 0             62  142  204
# 1             76   23   99
# All          138  165  303

# %%
sns.histplot(x = 'old_peak', data = df)
# Out:
# <AxesSubplot:xlabel='old_peak', ylabel='Count'>

# %%
#if old_peak is low, more likely to have a heart disease
sns.boxplot(x = 'target', y = 'old_peak', data = df)
# Out:
# <AxesSubplot:xlabel='target', ylabel='old_peak'>

# %%
sns.countplot(x = 'slope', data = df)
# Out:
# <AxesSubplot:xlabel='slope', ylabel='count'>

# %%
#As the slope increases, chances of having a heart disease also increases
pd.crosstab(df['slope'], df['target'], margins = all)
# Out:
# target    0    1  All
# slope
# 0        12    9   21
# 1        91   49  140
# 2        35  107  142
# All     138  165  303

# %%
sns.countplot(x = 'ca', data = df)
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %%
#As the slope increases, chances of having a heart disease decreases
pd.crosstab(df['ca'], df['target'], margins = all)
# Out:
# target    0    1  All
# ca
# 0        45  130  175
# 1        44   21   65
# 2        31    7   38
# 3        17    3   20
# 4         1    4    5
# All     138  165  303

# %%
sns.countplot(x = 'thalassemia', data = df)
# Out:
# <AxesSubplot:xlabel='thalassemia', ylabel='count'>

# %%
#if you are at thalassemia level 2, chances of having a heart disease are pretty high
pd.crosstab(df['thalassemia'], df['target'], margins = all)
# Out:
# target         0    1  All
# thalassemia
# 0              1    1    2
# 1             12    6   18
# 2             36  130  166
# 3             89   28  117
# All          138  165  303

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

# %%
calc_vif(X)
# Out:
#       variables        VIF
# 0           age  38.974608
# 1        gender   3.517713
# 2    chest_pain   2.383373
# 3      rest_bps  57.728559
# 4    cholestrol  26.249846
# 5      rest_ecg   2.049350
# 6       thalach  42.727168
# 7   exer_angina   2.018794
# 8      old_peak   3.038264
# 9         slope  10.001722
# 10           ca   1.772989
# 11  thalassemia  17.084207

# %%
X.drop('rest_bps', axis = 1, inplace = True)

# %%
calc_vif(X)
# Out:
#       variables        VIF
# 0           age  28.306670
# 1        gender   3.516270
# 2    chest_pain   2.367603
# 3    cholestrol  25.919460
# 4      rest_ecg   2.049230
# 5       thalach  33.973464
# 6   exer_angina   1.984014
# 7      old_peak   2.958494
# 8         slope   9.999867
# 9            ca   1.772951
# 10  thalassemia  16.948837

# %%
X.drop('thalach', axis = 1, inplace = True)

# %%
calc_vif(X)
# Out:
#      variables        VIF
# 0          age  26.867427
# 1       gender   3.404311
# 2   chest_pain   2.222881
# 3   cholestrol  22.373976
# 4     rest_ecg   2.014587
# 5  exer_angina   1.950282
# 6     old_peak   2.951575
# 7        slope   8.329321
# 8           ca   1.728598
# 9  thalassemia  15.923527

# %%
X.drop('age', axis = 1, inplace = True)

# %%
calc_vif(X)
# Out:
#      variables        VIF
# 0       gender   3.393847
# 1   chest_pain   2.157761
# 2   cholestrol  14.813785
# 3     rest_ecg   2.000625
# 4  exer_angina   1.940176
# 5     old_peak   2.821335
# 6        slope   7.963906
# 7           ca   1.668594
# 8  thalassemia  14.854008

# %%
X.drop('thalassemia', axis = 1, inplace = True)

# %%
calc_vif(X)
# Out:
#      variables        VIF
# 0       gender   3.041052
# 1   chest_pain   2.156272
# 2   cholestrol  10.441774
# 3     rest_ecg   1.960931
# 4  exer_angina   1.903390
# 5     old_peak   2.667746
# 6        slope   7.614291
# 7           ca   1.660809

# %%
X.drop('cholestrol', axis = 1, inplace = True)

# %%
calc_vif(X)
# Out:
#      variables       VIF
# 0       gender  3.028739
# 1   chest_pain  2.045062
# 2     rest_ecg  1.953107
# 3  exer_angina  1.783326
# 4     old_peak  2.062091
# 5        slope  3.756398
# 6           ca  1.639834

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
from sklearn.tree import DecisionTreeClassifier

#DecisionTreeClassifier?

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)

classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score

cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[26,  4],
#        [ 8, 23]], dtype=int64)

# %%
print("Accuracy = ", accuracy_score(y_test, y_pred))
print("ROC_AUC_Score = ", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy =  0.8032786885245902
# ROC_AUC_Score =  0.8043010752688172

# %%
from sklearn.model_selection import GridSearchCV
pGrid = {'max_depth': range(2, 10), # 8
        'min_samples_leaf': range(10, 51, 5),  # 10
        'min_samples_split': range(20, 81, 10)}   # 8

gscv_dt = GridSearchCV(estimator = DecisionTreeClassifier(), param_grid = pGrid, cv = 5,
                       scoring = 'recall', n_jobs = -1, verbose = True)

# %%
gscv_dt.fit(X, y)
# Out:
# Fitting 5 folds for each of 504 candidates, totalling 2520 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  56 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 2384 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 2520 out of 2520 | elapsed:    2.4s finished
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'max_depth': range(2, 10),
#                          'min_samples_leaf': range(10, 51, 5),
#                          'min_samples_split': range(20, 81, 10)},
#              scoring='recall', verbose=True)

# %%
gscv_dt.best_params_
# Out:
# {'max_depth': 2, 'min_samples_leaf': 20, 'min_samples_split': 20}

# %%
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0, max_depth = 2, min_samples_leaf = 20, min_samples_split = 20)

classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=2, min_samples_leaf=20,
#                        min_samples_split=20, random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[20, 10],
#        [ 0, 31]], dtype=int64)

# %%
print("Accuracy = ", accuracy_score(y_test, y_pred))
print("ROC_AUC_Score = ", roc_auc_score(y_test, y_pred))
# Out:
# Accuracy =  0.8360655737704918
# ROC_AUC_Score =  0.8333333333333334
